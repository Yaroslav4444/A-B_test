# %% [markdown]
# # Задание 1 . Выберите любой продукт.
# ## Например ваш продукт
# ### ozon.ru
# ### citilink.ru
# ### telegram
# ## Какие бы ключевые метрики вы выделили? Опишите почему вы выбрали именно их и можно ли их измерить

# %% [markdown]
# # Ozon
# ## Выделим 5 ключевых метрик:
# ### 1) Стоимость привлечения клиента - анализ этой метрики даст понимание окупаемости средств,вложенных в рекламу.
# ### 2) Конверсия в первую покупку - анализ этой метрики поможет увеличить окупаемость маркетинга и выявить слабые места процесса продаж.
# ### 3) Кол-во заказов на покупателя - анализ этой метрики поможет понять,что влияет на кол-во покупок,совершаемых за одно посещение.
# ### 4) Средний чек и издержки - анализ этой метрики даёт понимание покупательской способности аудитории, лояльности клиентов, эффективности маркетинга компании.
# ### 5) Кол-во товаров,купленных в рассрочку - анализ этой метрики даёт понимание о покупательской способности выбранной целевой аудитории.

# %% [markdown]
# # Задание 2.
# ## Сформулируйте 3-5 гипотез для выбранного продукта.

# %% [markdown]
# ## Гипотеза 1.
# ### Улучшив работу рекомендательного алгоритма мы повысим кол-во продаж. Логично предположить,что если покупателю будет предложен товар,который ему интересен,то он с большей вероятностью его купит.
# ## Гипотеза 2.
# ### Увеличив размер карточки товара есть вероятность увеличить кол-во заинтересованных в нём людей. Есть большое кол-во покупателей с плохим зрением,мелкие картинки,которые они не могут рассмотреть - проматывают.
# ## Гипотеза 3.
# ### Увеличив длительность рассрочки мы так же увеличим кол-во продаж. Увеличив длительность рассрочки можно уменьшить разовый платёж по рассрочке,увеличив кол-во покупателей которые могут позволить себе купить тот или иной продукт.
